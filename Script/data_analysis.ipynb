# %%
# %matplotlib notebook
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import scipy.stats as st
import pymongo

# %%
input_path = "/Users/prophet60091/Documents/GitHub/ETL_Proj/Script/"
filename1="IMDb movies.csv"
filename2="IMDb ratings.csv"
filename3="IMDb names.csv"
filename4="IMDb title_principals.csv"
fullpath1=os.path.join(input_path,filename1)
fullpath2=os.path.join(input_path,filename2)
fullpath3=os.path.join(input_path,filename3)
fullpath4=os.path.join(input_path,filename4)
movies=pd.read_csv(fullpath1)
ratings=pd.read_csv(fullpath2)
names=pd.read_csv(fullpath3)
title_principals=pd.read_csv(fullpath4)

# %%
movies_columns=['imdb_title_id','title','original_title','year','date_published','genre','duration','country','language','director','writer','production_company','budget','usa_gross_income','worlwide_gross_income']
names_columns=['imdb_name_id','name','birth_name','height','birth_year','date_of_birth','place_of_birth','death_year','date_of_death','spouses','divorces','spouses_with_children','children']
title_principals_columns=['imdb_title_id','imdb_name_id','category']
ratings_columns=['imdb_title_id','weighted_average_vote','total_votes','mean_vote','median_vote','votes_10','votes_9','votes_8','votes_7','votes_6','votes_5','votes_4','votes_3','votes_2','votes_1','allgenders_0age_avg_vote','allgenders_0age_votes','allgenders_18age_avg_vote','allgenders_18age_votes','allgenders_30age_avg_vote','allgenders_30age_votes','allgenders_45age_avg_vote','allgenders_45age_votes','males_0age_avg_vote','males_0age_votes','males_18age_avg_vote','males_18age_votes','males_30age_avg_vote','males_30age_votes','males_45age_avg_vote','males_45age_votes','females_0age_avg_vote','females_0age_votes','females_18age_avg_vote','females_18age_votes','females_30age_avg_vote','females_30age_votes','females_45age_avg_vote','females_45age_votes']

# %%
usefull_movies=movies[movies_columns].copy()
display(usefull_movies.head())
usefull_names=names[names_columns].copy()
display(usefull_names.head())
usefull_ratings=ratings[ratings_columns].copy()
display(usefull_ratings.head())
usefull_title_principals=title_principals[title_principals_columns].copy()
display(usefull_title_principals.head())
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     1906-12-26
# 1                                     Den sorte drøm  1911     1911-08-19
# 2                                          Cleopatra  1912     1912-11-13
# 3                                          L'Inferno  1911     1911-03-06
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
#
#                        genre  duration           country language  \
# ...

# %%
merged_data = pd.DataFrame.merge(usefull_title_principals,usefull_movies,how='left',on='imdb_title_id')
merged_data = merged_data.merge(usefull_names,how='left',on='imdb_name_id')
merged_data = merged_data.merge(usefull_ratings,how='left',on='imdb_title_id')
display(merged_data)
# Out:
#        imdb_title_id imdb_name_id         category  \
# 0          tt0000574    nm0846887          actress
# 1          tt0000574    nm0846894            actor
# 2          tt0000574    nm3002376            actor
# 3          tt0000574    nm0170118          actress
# 4          tt0000574    nm0846879         director
# ...              ...          ...              ...
# 377843     tt9903716   nm10532693         director
# 377844     tt9903716   nm10531260         producer
# 377845     tt9903716    nm6044359         composer
# 377846     tt9903716   nm10532695  cinematographer
# 377847     tt9903716    nm9492020           editor
#
#                               title               original_title    year  \
# 0       The Story of the Kelly Gang  The Story of the Kelly Gang  1906.0
# 1       The Story of the Kelly Gang  The Story of the Kelly Gang  1906.0
# 2       The Story of the Kelly Gang  The Story of the Kelly Gang  1906.0
# ...

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")

#DATABASE
db = myclient.IMDB_Database

#COLLECTION
movies_db=db.IMDB_Movies

# %%
data_dict = merged_data.to_dict("records")

for record in data_dict:
    movies_db.insert_one(record)

# %%
data_dict
# Out:
# [{'imdb_title_id': 'tt0000574',
#   'imdb_name_id': 'nm0846887',
#   'category': 'actress',
#   'title': 'The Story of the Kelly Gang',
#   'original_title': 'The Story of the Kelly Gang',
#   'year': 1906.0,
#   'date_published': '1906-12-26',
#   'genre': 'Biography, Crime, Drama',
#   'duration': 70.0,
#   'country': 'Australia',
#   'language': nan,
#   'director': 'Charles Tait',
#   'writer': 'Charles Tait',
#   'production_company': 'J. and N. Tait',
#   'budget': '$ 2250',
#   'usa_gross_income': nan,
#   'worlwide_gross_income': nan,
#   'name': 'Elizabeth Tait',
#   'birth_name': 'Elizabeth Tait',
#   'height': nan,
#   'birth_year': 1879.0,
#   'date_of_birth': '1879',
#   'place_of_birth': 'Australia',
#   'death_year': nan,
#   'date_of_death': nan,
#   'spouses': 0,
#   'divorces': 0,
#   'spouses_with_children': 0,
#   'children': 0,
#   'weighted_average_vote': 6.1,
#   'total_votes': 537.0,
#   'mean_vote': 6.3,
#   'median_vote': 6.0,
#   'votes_10': 54.0,
# ...
